# %%
from gensim.models import Word2Vec, KeyedVectors
import pandas as pd
import numpy as np

# %%
jamaal_df = pd.read_csv('./COVID19_mini.csv')
pd.set_option('display.max_colwidth',1)
jamaal_df.head()
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                                            text  \
# 0  RT @ashish_vaidya1: @Bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid19 ex-gratia claim from govt. Many c…
# 1  RT @TheAngryEpi: Informally reached out to a few epidemiologists about an open position in Arizona. Their response: “I would not work in AZ…
# 2  RT @sinovic: If this is a joke from the @DMRegister it really isn’t funny. If it’s serious, they are completely out of touch from reality w…
# 3  RT @MicahPollak: Well, #COVID19 is once again the leading cause of death in #Indiana (based on average daily deaths) and closing in on (aga…
#
#               user
# 0  ashish_vaidya1
# 1  greensnow
# 2  RadioBradshaw
# 3  KristinaTraxler

# %%
jamaal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  4 non-null      object
#  1   text       4 non-null      object
#  2   user       4 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes

# %%
jamaal_df= jamaal_df.drop(["user"],axis=1)
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                                            text
# 0  RT @ashish_vaidya1: @Bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid19 ex-gratia claim from govt. Many c…
# 1  RT @TheAngryEpi: Informally reached out to a few epidemiologists about an open position in Arizona. Their response: “I would not work in AZ…
# 2  RT @sinovic: If this is a joke from the @DMRegister it really isn’t funny. If it’s serious, they are completely out of touch from reality w…
# 3  RT @MicahPollak: Well, #COVID19 is once again the leading cause of death in #Indiana (based on average daily deaths) and closing in on (aga…

# %%
jamaal_df['text'] = jamaal_df['text'].str.split(':', n=1).str[1]
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                                text
# 0   @Bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid19 ex-gratia claim from govt. Many c…
# 1   Informally reached out to a few epidemiologists about an open position in Arizona. Their response: “I would not work in AZ…
# 2   If this is a joke from the @DMRegister it really isn’t funny. If it’s serious, they are completely out of touch from reality w…
# 3   Well, #COVID19 is once again the leading cause of death in #Indiana (based on average daily deaths) and closing in on (aga…

# %%
jamaal_df['text'] = jamaal_df['text'].str.lstrip("...")
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                                text
# 0   @Bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid19 ex-gratia claim from govt. Many c…
# 1   Informally reached out to a few epidemiologists about an open position in Arizona. Their response: “I would not work in AZ…
# 2   If this is a joke from the @DMRegister it really isn’t funny. If it’s serious, they are completely out of touch from reality w…
# 3   Well, #COVID19 is once again the leading cause of death in #Indiana (based on average daily deaths) and closing in on (aga…

# %%
jamaal_df['text'] = jamaal_df['text'].str.replace('@', '')
jamaal_df['text'] = jamaal_df['text'].str.replace('#', '')
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                               text
# 0   Bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid19 ex-gratia claim from govt. Many c…
# 1   Informally reached out to a few epidemiologists about an open position in Arizona. Their response: “I would not work in AZ…
# 2   If this is a joke from the DMRegister it really isn’t funny. If it’s serious, they are completely out of touch from reality w…
# 3   Well, COVID19 is once again the leading cause of death in Indiana (based on average daily deaths) and closing in on (aga…

# %%
jamaal_df['text'] = jamaal_df['text'].str.lower()
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                               text
# 0   bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid19 ex-gratia claim from govt. many c…
# 1   informally reached out to a few epidemiologists about an open position in arizona. their response: “i would not work in az…
# 2   if this is a joke from the dmregister it really isn’t funny. if it’s serious, they are completely out of touch from reality w…
# 3   well, covid19 is once again the leading cause of death in indiana (based on average daily deaths) and closing in on (aga…

# %%
jamaal_df['text'] = jamaal_df['text'].str.replace("\d+", "",regex=True)
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                               text
# 0   bhupendrapbjp sir, keshod mamlatdar office says they didnt receive grant for covid ex-gratia claim from govt. many c…
# 1   informally reached out to a few epidemiologists about an open position in arizona. their response: “i would not work in az…
# 2   if this is a joke from the dmregister it really isn’t funny. if it’s serious, they are completely out of touch from reality w…
# 3   well, covid is once again the leading cause of death in indiana (based on average daily deaths) and closing in on (aga…

# %%
import string

jamaal_df['text'] = jamaal_df['text'].str.translate(str.maketrans('', '', string.punctuation))
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                             text
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c…
# 1   informally reached out to a few epidemiologists about an open position in arizona their response “i would not work in az…
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w…
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga…

# %%
jamaal_df['text'] = jamaal_df['text'].str.replace('…', '')
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                            text
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c
# 1   informally reached out to a few epidemiologists about an open position in arizona their response “i would not work in az
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga

# %%
jamaal_df['text'] = jamaal_df['text'].str.replace('“', '')
jamaal_df
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                            text
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c
# 1   informally reached out to a few epidemiologists about an open position in arizona their response i would not work in az
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga

# %%
missing_rows = jamaal_df.isnull().sum(axis=1)
num_missing_rows = len(missing_rows[missing_rows > 0])
print(f"Number of missing rows: {num_missing_rows}")
# Out:
# Number of missing rows: 0

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw

gn_vec_path = "GoogleNews-vectors-negative300.bin"
aug = naw.WordEmbsAug(
    model_type='word2vec', model_path=gn_vec_path,
    action="insert")

jamaal_df_after_word_augmenter = jamaal_df.copy()

for i in range(len(jamaal_df_after_word_augmenter)):
    text = jamaal_df_after_word_augmenter['text'][i]
    augmented_text = aug.augment(text)
    jamaal_df_after_word_augmenter['text'][i] = augmented_text

jamaal_df_after_word_augmenter
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                                                                                                            text
# 0  [bhupendrapbjp sir Flaco keshod mamlatdar office says they didnt BY receive grant sandbagged for covid Pearson exgratia Appro claim from govt many Kadan c]
# 1  [informally reached out Doneckers to a few epidemiologists about Laurelton an open godfather position Antonio in Lorenz arizona their response Sukhia i would dean not work in az]
# 2  [if this Capt. is WA a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s Scoropanos serious EMD they are completely Boschker out of blackout touch SiliconServer from reality w]
# 3  [well Pouyan covid is once Judge again licencia the leading cause of death in artillery indiana based Shellhammer on average daily Al deaths and closing in on HDFC aga]

# %%
jamaal_df_after_word_augmenter['text'] = jamaal_df_after_word_augmenter['text'].apply(' '.join)
jamaal_df_after_word_augmenter
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
#
#                                                                                                                                                                                                          text
# 0  bhupendrapbjp sir Flaco keshod mamlatdar office says they didnt BY receive grant sandbagged for covid Pearson exgratia Appro claim from govt many Kadan c
# 1  informally reached out Doneckers to a few epidemiologists about Laurelton an open godfather position Antonio in Lorenz arizona their response Sukhia i would dean not work in az
# 2  if this Capt. is WA a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s Scoropanos serious EMD they are completely Boschker out of blackout touch SiliconServer from reality w
# 3  well Pouyan covid is once Judge again licencia the leading cause of death in artillery indiana based Shellhammer on average daily Al deaths and closing in on HDFC aga

# %%
jamaal_df_after_word_augmenter = pd.concat(
    [jamaal_df, jamaal_df_after_word_augmenter], ignore_index=True)


jamaal_df_after_word_augmenter
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
# 4  positive
# 5  negative
# 6  positive
# 7  negative
#
#                                                                                                                                                                                                          text
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c
# 1   informally reached out to a few epidemiologists about an open position in arizona their response i would not work in az
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga
# 4  bhupendrapbjp sir Flaco keshod mamlatdar office says they didnt BY receive grant sandbagged for covid Pearson exgratia Appro claim from govt many Kadan c
# 5  informally reached out Doneckers to a few epidemiologists about Laurelton an open godfather position Antonio in Lorenz arizona their response Sukhia i would dean not work in az
# 6  if this Capt. is WA a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s Scoropanos serious EMD they are completely Boschker out of blackout touch SiliconServer from reality w
# 7  well Pouyan covid is once Judge again licencia the leading cause of death in artillery indiana based Shellhammer on average daily Al deaths and closing in on HDFC aga

# %%
import string
jamaal_df_after_word_augmenter['text'] = jamaal_df_after_word_augmenter['text'].str.lower()
jamaal_df_after_word_augmenter['text'] = jamaal_df_after_word_augmenter['text'].str.translate(str.maketrans('', '', string.punctuation))
jamaal_df_after_word_augmenter['text'] = jamaal_df_after_word_augmenter['text'].str.replace("\d+", "", regex=True)
jamaal_df_after_word_augmenter

jamaal_df_after_word_augmenter
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
# 4  positive
# 5  negative
# 6  positive
# 7  negative
#
#                                                                                                                                                                                                         text
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c
# 1   informally reached out to a few epidemiologists about an open position in arizona their response i would not work in az
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga
# 4  bhupendrapbjp sir flaco keshod mamlatdar office says they didnt by receive grant sandbagged for covid pearson exgratia appro claim from govt many kadan c
# 5  informally reached out doneckers to a few epidemiologists about laurelton an open godfather position antonio in lorenz arizona their response sukhia i would dean not work in az
# 6  if this capt is wa a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s scoropanos serious emd they are completely boschker out of blackout touch siliconserver from reality w
# 7  well pouyan covid is once judge again licencia the leading cause of death in artillery indiana based shellhammer on average daily al deaths and closing in on hdfc aga

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import string
import re

nltk.download('stopwords')
nltk.download('punkt')
stop_words_nltk = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Setup\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Setup\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text_string = ' '.join(jamaal_df_after_word_augmenter['text'])
print(text_string)
# Out:
#  bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c  informally reached out to a few epidemiologists about an open position in arizona their response i would not work in az  if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w  well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga bhupendrapbjp sir flaco keshod mamlatdar office says they didnt by receive grant sandbagged for covid pearson exgratia appro claim from govt many kadan c informally reached out doneckers to a few epidemiologists about laurelton an open godfather position antonio in lorenz arizona their response sukhia i would dean not work in az if this capt is wa a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s scoropanos serious emd they are completely boschker out of blackout touch siliconserver from reality w well pouyan covid is once judge again licencia the leading cause of death in artillery indiana based shellhammer on average daily al deaths and closing in on hdfc aga

# %%
tokenized_corpus_nltk = word_tokenize(text_string)

# %%
tokenized_corpus_without_stopwords = [
    i for i in tokenized_corpus_nltk if not i in stop_words_nltk]
print("Tokenized corpus without stopwords:",
      tokenized_corpus_without_stopwords)
# Out:
# Tokenized corpus without stopwords: ['bhupendrapbjp', 'sir', 'keshod', 'mamlatdar', 'office', 'says', 'didnt', 'receive', 'grant', 'covid', 'exgratia', 'claim', 'govt', 'many', 'c', 'informally', 'reached', 'epidemiologists', 'open', 'position', 'arizona', 'response', 'would', 'work', 'az', 'joke', 'dmregister', 'really', '’', 'funny', '’', 'serious', 'completely', 'touch', 'reality', 'w', 'well', 'covid', 'leading', 'cause', 'death', 'indiana', 'based', 'average', 'daily', 'deaths', 'closing', 'aga', 'bhupendrapbjp', 'sir', 'flaco', 'keshod', 'mamlatdar', 'office', 'says', 'didnt', 'receive', 'grant', 'sandbagged', 'covid', 'pearson', 'exgratia', 'appro', 'claim', 'govt', 'many', 'kadan', 'c', 'informally', 'reached', 'doneckers', 'epidemiologists', 'laurelton', 'open', 'godfather', 'position', 'antonio', 'lorenz', 'arizona', 'response', 'sukhia', 'would', 'dean', 'work', 'az', 'capt', 'wa', 'joke', 'dmregister', 'really', 'tramadol', '’', 'funny', 'incumbent', '’', 'scoropanos', 'serious', 'emd', 'completely', 'boschker', 'blackout', 'touch', 'siliconserver', 'reality', 'w', 'well', 'pouyan', 'covid', 'judge', 'licencia', 'leading', 'cause', 'death', 'artillery', 'indiana', 'based', 'shellhammer', 'average', 'daily', 'al', 'deaths', 'closing', 'hdfc', 'aga']

# %%
pretrainedpath = "GoogleNews-vectors-negative300.bin"
w2v_model = KeyedVectors.load_word2vec_format(pretrainedpath, binary=True)

# %%
aug = naw.WordEmbsAug(
    model_type='word2vec', model_path=gn_vec_path,
    action="substitute", aug_max=2, aug_min=2)
new_texts = []
for i in range(len(jamaal_df_after_word_augmenter)):
    text = jamaal_df_after_word_augmenter['text'][i]
    augmented_text = aug.augment(text)
    new_texts.append(augmented_text)

jamaal_df_after_word_augmenter = jamaal_df_after_word_augmenter.assign(new_text = new_texts)
jamaal_df_after_word_augmenter
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
# 4  positive
# 5  negative
# 6  positive
# 7  negative
#
#                                                                                                                                                                                                         text  \
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c
# 1   informally reached out to a few epidemiologists about an open position in arizona their response i would not work in az
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga
# 4  bhupendrapbjp sir flaco keshod mamlatdar office says they didnt by receive grant sandbagged for covid pearson exgratia appro claim from govt many kadan c
# 5  informally reached out doneckers to a few epidemiologists about laurelton an open godfather position antonio in lorenz arizona their response sukhia i would dean not work in az
# 6  if this capt is wa a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s scoropanos serious emd they are completely boschker out of blackout touch siliconserver from reality w
# 7  well pouyan covid is once judge again licencia the leading cause of death in artillery indiana based shellhammer on average daily al deaths and closing in on hdfc aga
#
#                                                                                                                                                                                                                 new_text
# 0  [bhupendrapbjp sir keshod mamlatdar office feels they didnt receive grant for covid exgratia claim later govt many c]
# 1  [informally swithee@cnc.com out to a few epidemiologists about bona_fide open position in arizona their response i would not work in az]
# 2  [if this is a joke from Verlander_trotted dmregister it really isn ’ t funny if it ’ s serious they are completely out of touch across reality w]
# 3  [such covid is once again the leading cause of ligature_strangulation in indiana based on average daily deaths and closing in on aga]
# 4  [bhupendrapbjp sir flaco keshod mamlatdar office says they didnt by receive grant sandbagged for covid frazier exgratia appro claim from gov't many kadan c]
# 5  [informally Reporter_Lesley_Stedman out doneckers to a ten epidemiologists about laurelton an open godfather position antonio in lorenz arizona their response sukhia i would dean not work in az]
# 6  [if this capt is wa a joke from the dmregister it really isn_¿ tramadol ’ t funny incumbent if it ’ s scoropanos serious emd they are completely boschker Spillborghs of blackout touch siliconserver from reality w]
# 7  [well pouyan covid Isn'ta once judge again licencia the leading cause of death in artillery indiana based shellhammer on average daily al deaths and closing in close hdfc aga]

# %%
jamaal_df_after_word_augmenter['new_text'] = jamaal_df_after_word_augmenter['new_text'].apply(
    ' '.join)
jamaal_df_after_word_augmenter
# Out:
#   sentiment  \
# 0  positive
# 1  negative
# 2  positive
# 3  negative
# 4  positive
# 5  negative
# 6  positive
# 7  negative
#
#                                                                                                                                                                                                         text  \
# 0   bhupendrapbjp sir keshod mamlatdar office says they didnt receive grant for covid exgratia claim from govt many c
# 1   informally reached out to a few epidemiologists about an open position in arizona their response i would not work in az
# 2   if this is a joke from the dmregister it really isn’t funny if it’s serious they are completely out of touch from reality w
# 3   well covid is once again the leading cause of death in indiana based on average daily deaths and closing in on aga
# 4  bhupendrapbjp sir flaco keshod mamlatdar office says they didnt by receive grant sandbagged for covid pearson exgratia appro claim from govt many kadan c
# 5  informally reached out doneckers to a few epidemiologists about laurelton an open godfather position antonio in lorenz arizona their response sukhia i would dean not work in az
# 6  if this capt is wa a joke from the dmregister it really isn tramadol ’ t funny incumbent if it ’ s scoropanos serious emd they are completely boschker out of blackout touch siliconserver from reality w
# 7  well pouyan covid is once judge again licencia the leading cause of death in artillery indiana based shellhammer on average daily al deaths and closing in on hdfc aga
#
#                                                                                                                                                                                                               new_text
# 0  bhupendrapbjp sir keshod mamlatdar office feels they didnt receive grant for covid exgratia claim later govt many c
# 1  informally swithee@cnc.com out to a few epidemiologists about bona_fide open position in arizona their response i would not work in az
# 2  if this is a joke from Verlander_trotted dmregister it really isn ’ t funny if it ’ s serious they are completely out of touch across reality w
# 3  such covid is once again the leading cause of ligature_strangulation in indiana based on average daily deaths and closing in on aga
# 4  bhupendrapbjp sir flaco keshod mamlatdar office says they didnt by receive grant sandbagged for covid frazier exgratia appro claim from gov't many kadan c
# 5  informally Reporter_Lesley_Stedman out doneckers to a ten epidemiologists about laurelton an open godfather position antonio in lorenz arizona their response sukhia i would dean not work in az
# 6  if this capt is wa a joke from the dmregister it really isn_¿ tramadol ’ t funny incumbent if it ’ s scoropanos serious emd they are completely boschker Spillborghs of blackout touch siliconserver from reality w
# 7  well pouyan covid Isn'ta once judge again licencia the leading cause of death in artillery indiana based shellhammer on average daily al deaths and closing in close hdfc aga

# %%
jamaal_df_after_word_augmenter.to_csv('jamaal_df_after_random_insertion.txt', sep=' ', index=False)
